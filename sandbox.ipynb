# %%
import pandas as pd

df = pd.read_json("multilingual_data/xor_attriqa/in-language/fi.jsonl", lines=True)
df.head()
# Out:
#                                         query query_language
# 0             Asuuko Itämeressä norppia? [fi]             fi  \
# 1  Harjoitetaanko Japanissa maataloutta? [fi]             fi
# 2         Kasvatetaanko Suomessa sikoja? [fi]             fi
# 3             Kuika sukupuoli määräytyy? [fi]             fi
# 4        Kuinka Ateenan tyrannia loppui? [fi]             fi
#
#                                              answers
# 0                                            ['yes']  \
# 1  ['Maatalous, viljely ja kalastus muodostavat p...
# 2                                            ['yes']
# 3  ['joukko maskuliinisuuteen ja feminiinisyyteen...
# 4                               ['510-luvulla eaa.']
#
#                                           prediction  prediction_correct
# 0                                                yes                True  \
# 1                                                yes               False
# ...
